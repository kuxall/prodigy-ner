# %% [markdown]
# # Span Categorization

# %% [markdown]
# ### For Help

# %%
# !python -m prodigy spans.manual --help

# %% [markdown]
# **PLEASE USE THIS COMMAND IN TERMINAL NOT IN NOTEBOOK**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# !python -m prodigy spans.manual block_resume blank:en /home/kushal/Dropbox/'sherpa codes'/services/'data annotations'/dolphin/corpus/corpus.jsonl --label EXPERIENCE,EXPERIENCE_ORGANIZATION,EXPERIENCE_ADDRESS,EXPERIENCE_STARTDATE,EXPERIENCE_ENDDATE,EXPERIENCE_SKILLS,EXPERIENCE_KNOWLEDGE
